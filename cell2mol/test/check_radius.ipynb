# %%
from cell2mol.elementdata import ElementData
elemdatabase = ElementData()
from cell2mol.coordination_sphere import covalent_factor_for_metal_v2

# %%
1.3*(elemdatabase.CovalentRadius3["Au"] + elemdatabase.CovalentRadius3["Mn"])
# Out:
# 3.575

# %%
1.3*(elemdatabase.CovalentRadius3["Fe"] + elemdatabase.CovalentRadius3["N"])
# Out:
# 2.6390000000000002

# %%
covalent_factor_for_metal_v2
# Out:
# {'H': 1.19,
#  'D': 1.19,
#  'He': 1.68,
#  'Li': 0.99,
#  'Be': 0.95,
#  'B': 1.1,
#  'C': 1.22,
#  'N': 1.19,
#  'O': 1.21,
#  'F': 1.14,
#  'Ne': 1.56,
#  'Na': 0.88,
#  'Mg': 1.04,
#  'Al': 1.32,
#  'Si': 1.06,
#  'P': 1.14,
#  'S': 1.19,
#  'Cl': 1.19,
#  'Ar': 1.5,
#  'K': 0.79,
#  'Ca': 0.97,
#  'Sc': 1.3,
#  'Ti': 1.3,
#  'V': 1.3,
#  'Cr': 1.3,
#  'Mn': 1.3,
#  'Fe': 1.3,
#  'Co': 1.3,
#  'Ni': 1.3,
#  'Cu': 1.3,
#  'Zn': 1.3,
#  'Ga': 1.26,
#  'Ge': 1.24,
#  'As': 1.12,
#  'Se': 1.12,
#  'Br': 1.21,
#  'Kr': 1.6,
#  'Rb': 1.02,
#  'Sr': 0.97,
#  'Y': 1.3,
#  'Zr': 1.3,
#  'Nb': 1.3,
#  'Mo': 1.3,
#  'Tc': 1.3,
#  'Ru': 1.3,
#  'Rh': 1.3,
#  'Pd': 1.3,
#  'Ag': 1.3,
#  'Cd': 1.3,
#  'In': 1.35,
#  'Sn': 1.29,
#  'Sb': 1.04,
#  'Te': 1.06,
#  'I': 1.21,
#  'Xe': 1.51,
#  'Cs': 1.03,
#  'Ba': 0.99,
#  'La': 1.3,
#  'Ce': 1.3,
#  'Pr': 1.3,
#  'Nd': 1.3,
#  'Pm': 1.3,
#  'Sm': 1.3,
#  'Eu': 1.3,
#  'Gd': 1.3,
#  'Tb': 1.3,
#  'Dy': 1.3,
#  'Ho': 1.3,
#  'Er': 1.3,
#  'Tm': 1.3,
#  'Yb': 1.3,
#  'Lu': 1.3,
#  'Hf': 1.3,
#  'Ta': 1.3,
#  'W': 1.3,
#  'Re': 1.3,
#  'Os': 1.3,
#  'Ir': 1.3,
#  'Pt': 1.3,
#  'Au': 1.3,
#  'Hg': 1.3,
#  'Tl': 1.3,
#  'Pb': 1.29,
#  'Bi': 1.28,
#  'Po': 1.38,
#  'At': 1.34,
#  'Rn': 1.63,
#  'Fr': 1.09,
#  'Ra': 1.16,
#  'Ac': 1.3,
#  'Th': 1.3,
#  'Pa': 1.3,
#  'U': 1.3,
#  'Np': 1.3,
#  'Pu': 1.3,
#  'Am': 1.3,
#  'Cm': 1.3,
#  'Bk': 1.3,
#  'Cf': 1.3,
#  'Es': 1.3,
#  'Fm': 1.3,
#  'Md': 1.3,
#  'No': 1.3,
#  'Lr': 1.3,
#  'Rf': 1.3,
#  'Db': 1.3,
#  'Sg': 1.3,
#  'Bh': 1.3,
#  'Hs': 1.3,
#  'Mt': 1.3}

# %%
elemdatabase = ElementData()

# %%
for elem in elemdatabase.elementgroup.keys():
    if elemdatabase.elementgroup[elem] == 1 or elemdatabase.elementgroup[elem] == 2:
        print(elem, elemdatabase.CovalentRadius2[elem], elemdatabase.CovalentRadius3[elem], 
              round(elemdatabase.CovalentRadius3[elem]/elemdatabase.CovalentRadius2[elem],2),)
            #   covalent_factor_for_metal_v2[elem],
            #   round(elemdatabase.CovalentRadius3[elem]*covalent_factor_for_metal_v2[elem],2),
            #    round(elemdatabase.CovalentRadius3[elem]*0.6, 2) )
# Out:
# H 0.23 0.31 1.35
# D 0.23 0.31 1.35
# Li 0.68 1.28 1.88
# Be 0.35 0.96 2.74
# Na 0.68 1.66 2.44
# Mg 0.88 1.41 1.6
# K 0.68 2.03 2.99
# Ca 0.99 1.76 1.78
# Rb 1.47 2.2 1.5
# Sr 1.12 1.95 1.74
# Cs 1.67 2.44 1.46
# Ba 1.34 2.15 1.6
# Fr 2.0 2.6 1.3
# Ra 1.9 2.21 1.16

# %%
            "Na1+": 0.970,
            "Mg1+": 0.820,
            "Mg2+": 0.660,
            "K1+": 1.330,
            "Ca1+": 1.180,
            "Ca2+": 0.990,
